# %% [markdown]
# <a href="https://colab.research.google.com/github/shubh45-nandan/CNN-RL-Hybrid-Models-for-CRC-/blob/main/resnet%2Bppo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📘 ResNet50 Fine-Tuning for Colorectal Histology

# ---- Installs ----
# !pip install -q tensorflow keras opencv-python matplotlib seaborn scikit-learn

# ---- Mount Drive ----
from google.colab import drive
drive.mount('/content/drive')

# ---- Imports ----
import os, glob, shutil, random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet import preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras import regularizers, callbacks, optimizers

print("✅ Libraries ready")

# ==========================================================
# 📦 ZIP Extraction
# ==========================================================
ZIP_IN_DRIVE = "/content/drive/MyDrive/archive.zip"  # change if needed

if not ZIP_IN_DRIVE or not os.path.exists(ZIP_IN_DRIVE):
    raise FileNotFoundError("❌ ZIP_IN_DRIVE path is not set correctly.")

EXTRACT_DIR = "/content/Extracted_Kather"
if os.path.exists(EXTRACT_DIR):
    shutil.rmtree(EXTRACT_DIR)
os.makedirs(EXTRACT_DIR, exist_ok=True)

print(f"📦 Unzipping dataset from:\n→ {ZIP_IN_DRIVE}")
# !unzip -q -o "$ZIP_IN_DRIVE" -d "$EXTRACT_DIR"

# Auto-detect dataset root
def find_dataset_root(base):
    best, best_count = base, 0
    for root, dirs, _ in os.walk(base):
        if len(dirs) > best_count:
            best, best_count = root, len(dirs)
    return best

SOURCE_DIR = find_dataset_root(EXTRACT_DIR)
print(f"✅ Dataset root detected at: {SOURCE_DIR}")

# ==========================================================
# ⚙️ Reproducibility & Split Ratios
# ==========================================================
SEED = 42
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)

VAL_RATIO = 0.20
TEST_RATIO = 0.15
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

EXTS = (".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff")

# ==========================================================
# 🔎 Discover Classes & Files
# ==========================================================
def list_images_recursive(folder):
    out = []
    for root, _, files in os.walk(folder):
        for fn in files:
            if os.path.splitext(fn)[1].lower() in EXTS:
                out.append(os.path.join(root, fn))
    return sorted(out)

class_to_files = {}
for cls in sorted(os.listdir(SOURCE_DIR)):
    p = os.path.join(SOURCE_DIR, cls)
    if os.path.isdir(p):
        files = list_images_recursive(p)
        if files:
            class_to_files[cls] = files

available_classes = sorted(class_to_files.keys())
if len(available_classes) == 0:
    raise RuntimeError("❌ No classes detected! Check ZIP structure.")

print("\n📚 Classes detected:")
for c in available_classes:
    print(f"  - {c}: {len(class_to_files[c])} images")

# ==========================================================
# 🧩 Stratified Split
# ==========================================================
SPLIT_ROOT = "/content/kather_split_resnet"
TRAIN_DIR = SPLIT_ROOT + "/train"
VAL_DIR   = SPLIT_ROOT + "/val"
TEST_DIR  = SPLIT_ROOT + "/test"

if os.path.exists(SPLIT_ROOT):
    shutil.rmtree(SPLIT_ROOT)
os.makedirs(TRAIN_DIR); os.makedirs(VAL_DIR); os.makedirs(TEST_DIR)

def allocate_counts(n, val_ratio=VAL_RATIO, test_ratio=TEST_RATIO):
    if n <= 0: return (0,0,0)
    if n == 1: return (1,0,0)
    if n == 2: return (1,0,1)
    test_n = max(1, int(n * test_ratio))
    val_n  = max(1, int(n * val_ratio))
    if test_n + val_n >= n:
        val_n = 1; test_n = 1
    train_n = n - val_n - test_n
    return (train_n, val_n, test_n)

rng = np.random.default_rng(SEED)
totals = {"train":0,"val":0,"test":0}

for cls in available_classes:
    files = class_to_files[cls]
    idx = np.arange(len(files))
    rng.shuffle(idx)

    train_n, val_n, test_n = allocate_counts(len(files))
    train_idx = set(idx[:train_n])
    val_idx   = set(idx[train_n:train_n+val_n])
    test_idx  = set(idx[train_n+val_n:train_n+val_n+test_n])

    os.makedirs(f"{TRAIN_DIR}/{cls}")
    os.makedirs(f"{VAL_DIR}/{cls}")
    os.makedirs(f"{TEST_DIR}/{cls}")

    for i in idx:
        src = files[i]
        base = os.path.basename(src)
        if i in train_idx: dst = f"{TRAIN_DIR}/{cls}/{base}"
        elif i in val_idx: dst = f"{VAL_DIR}/{cls}/{base}"
        else:              dst = f"{TEST_DIR}/{cls}/{base}"
        shutil.copy2(src, dst)

    totals["train"] += train_n
    totals["val"]   += val_n
    totals["test"]  += test_n

print("\n✅ Stratified Split Completed:")
print(totals)

# ==========================================================
# 🔄 Data Generators
# ==========================================================
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.2, height_shift_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True, vertical_flip=True,
    brightness_range=[0.8,1.2],
    shear_range=0.2,
    fill_mode="reflect"
)

val_test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_gen = train_datagen.flow_from_directory(TRAIN_DIR, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True)
val_gen   = val_test_datagen.flow_from_directory(VAL_DIR, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
test_gen  = val_test_datagen.flow_from_directory(TEST_DIR, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)

class_names = list(train_gen.class_indices.keys())
num_classes = len(class_names)
print(f"\n✅ Detected {num_classes} classes: {class_names}")

# ==========================================================
# 🧠 Build ResNet50 Baseline Model
# ==========================================================
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=IMG_SIZE + (3,))
base_model.trainable = False

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    BatchNormalization(),
    Dense(512, activation='relu', kernel_regularizer=regularizers.l2(1e-4)),
    Dropout(0.5),
    BatchNormalization(),
    Dense(256, activation='relu'),
    Dropout(0.3),
    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# ==========================================================
# 🏋️ Training Phase 1
# ==========================================================
checkpoint_cb = callbacks.ModelCheckpoint('/content/resnet50_best_phase1.h5', save_best_only=True, monitor='val_loss', mode='min')
earlystop_cb = callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-7)

EPOCHS_INITIAL = 15
history = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS_INITIAL, callbacks=[checkpoint_cb, earlystop_cb, reduce_lr])

# ==========================================================
# 🔓 Fine-tuning Phase
# ==========================================================
base_model.trainable = True
for layer in base_model.layers[:100]:  # Freeze early convolutional layers
    layer.trainable = False

model.compile(optimizer=optimizers.Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

EPOCHS_FINE = 25
history_fine = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS_FINE, callbacks=[checkpoint_cb, earlystop_cb, reduce_lr])

# ==========================================================
# 🧾 Evaluation
# ==========================================================
model.load_weights('/content/resnet50_best_phase1.h5')
test_loss, test_acc = model.evaluate(test_gen, verbose=1)
print(f"\n✅ Test Accuracy: {test_acc*100:.2f}%")
print(f"✅ Test Loss: {test_loss:.4f}")

# Confusion Matrix
y_true = test_gen.classes
y_pred = np.argmax(model.predict(test_gen, verbose=0), axis=1)
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix — ResNet50 Baseline")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=class_names))

# ==========================================================
# 🧭 Training vs Validation Curves
# ==========================================================
acc = history.history['accuracy'] + history_fine.history['accuracy']
val_acc = history.history['val_accuracy'] + history_fine.history['val_accuracy']
loss = history.history['loss'] + history_fine.history['loss']
val_loss = history.history['val_loss'] + history_fine.history['val_loss']

plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
plt.plot(acc, label='Train Accuracy')
plt.plot(val_acc, label='Val Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")

plt.subplot(1,2,2)
plt.plot(loss, label='Train Loss')
plt.plot(val_loss, label='Val Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.show()

# ==========================================================
# 💾 Save Final Model
# ==========================================================
model.save('/content/colorectal_resnet50_finetuned_final.h5')
print("✅ Final Model Saved at /content/colorectal_resnet50_finetuned_final.h5")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Libraries ready
# 📦 Unzipping dataset from:
# → /content/drive/MyDrive/archive.zip
# ✅ Dataset root detected at: /content/Extracted_Kather/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000
#
# 📚 Classes detected:
#   - 01_TUMOR: 625 images
#   - 02_STROMA: 625 images
#   - 03_COMPLEX: 625 images
#   - 04_LYMPHO: 625 images
#   - 05_DEBRIS: 625 images
#   - 06_MUCOSA: 625 images
#   - 07_ADIPOSE: 625 images
#   - 08_EMPTY: 625 images
#
# ✅ Stratified Split Completed:
# {'train': 3256, 'val': 1000, 'test': 744}
# Found 3256 images belonging to 8 classes.
# Found 1000 images belonging to 8 classes.
# Found 744 images belonging to 8 classes.
#
# ✅ Detected 8 classes: ['01_TUMOR', '02_STROMA', '03_COMPLEX', '04_LYMPHO', '05_DEBRIS', '06_MUCOSA', '07_ADIPOSE', '08_EMPTY']
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 2048)           │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │         2,056 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,780,424 (94.53 MB)
#  Trainable params: 1,187,592 (4.53 MB)
#  Non-trainable params: 23,592,832 (90.00 MB)
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - accuracy: 0.3652 - loss: 1.9412
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 83s 653ms/step - accuracy: 0.3664 - loss: 1.9374 - val_accuracy: 0.7410 - val_loss: 0.8784 - learning_rate: 1.0000e-04
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - accuracy: 0.6583 - loss: 1.0545
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 505ms/step - accuracy: 0.6586 - loss: 1.0538 - val_accuracy: 0.8370 - val_loss: 0.6068 - learning_rate: 1.0000e-04
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - accuracy: 0.7200 - loss: 0.8689
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 57s 564ms/step - accuracy: 0.7202 - loss: 0.8684 - val_accuracy: 0.8560 - val_loss: 0.5039 - learning_rate: 1.0000e-04
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.7761 - loss: 0.7257
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 506ms/step - accuracy: 0.7761 - loss: 0.7259 - val_accuracy: 0.8730 - val_loss: 0.4430 - learning_rate: 1.0000e-04
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.7979 - loss: 0.6766
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 513ms/step - accuracy: 0.7979 - loss: 0.6766 - val_accuracy: 0.8890 - val_loss: 0.4150 - learning_rate: 1.0000e-04
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.8190 - loss: 0.6272
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 513ms/step - accuracy: 0.8189 - loss: 0.6272 - val_accuracy: 0.8870 - val_loss: 0.3960 - learning_rate: 1.0000e-04
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.8037 - loss: 0.6321
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 510ms/step - accuracy: 0.8037 - loss: 0.6322 - val_accuracy: 0.8950 - val_loss: 0.3780 - learning_rate: 1.0000e-04
# Epoch 8/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.8236 - loss: 0.5950
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 51s 505ms/step - accuracy: 0.8236 - loss: 0.5948 - val_accuracy: 0.8970 - val_loss: 0.3732 - learning_rate: 1.0000e-04
# Epoch 9/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.8221 - loss: 0.5902
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 503ms/step - accuracy: 0.8222 - loss: 0.5902 - val_accuracy: 0.8980 - val_loss: 0.3657 - learning_rate: 1.0000e-04
# Epoch 10/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.8443 - loss: 0.5134
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 506ms/step - accuracy: 0.8443 - loss: 0.5136 - val_accuracy: 0.8990 - val_loss: 0.3532 - learning_rate: 1.0000e-04
# Epoch 11/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.8470 - loss: 0.5150
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 513ms/step - accuracy: 0.8470 - loss: 0.5152 - val_accuracy: 0.9040 - val_loss: 0.3466 - learning_rate: 1.0000e-04
# Epoch 12/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.8508 - loss: 0.5085
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 512ms/step - accuracy: 0.8508 - loss: 0.5085 - val_accuracy: 0.9070 - val_loss: 0.3366 - learning_rate: 1.0000e-04
# Epoch 13/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.8590 - loss: 0.5011
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 514ms/step - accuracy: 0.8590 - loss: 0.5011 - val_accuracy: 0.9150 - val_loss: 0.3296 - learning_rate: 1.0000e-04
# Epoch 14/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.8548 - loss: 0.5148
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 53s 521ms/step - accuracy: 0.8547 - loss: 0.5148 - val_accuracy: 0.9150 - val_loss: 0.3222 - learning_rate: 1.0000e-04
# Epoch 15/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 512ms/step - accuracy: 0.8724 - loss: 0.4379 - val_accuracy: 0.9200 - val_loss: 0.3265 - learning_rate: 1.0000e-04
# Epoch 1/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 109s 727ms/step - accuracy: 0.7950 - loss: 0.6773 - val_accuracy: 0.8980 - val_loss: 0.3535 - learning_rate: 1.0000e-05
# Epoch 2/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 538ms/step - accuracy: 0.8268 - loss: 0.5451 - val_accuracy: 0.9120 - val_loss: 0.3433 - learning_rate: 1.0000e-05
# Epoch 3/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 531ms/step - accuracy: 0.8696 - loss: 0.4683 - val_accuracy: 0.9190 - val_loss: 0.3275 - learning_rate: 1.0000e-05
# Epoch 4/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.8575 - loss: 0.4901
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 541ms/step - accuracy: 0.8575 - loss: 0.4901 - val_accuracy: 0.9240 - val_loss: 0.3135 - learning_rate: 1.0000e-05
# Epoch 5/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.8534 - loss: 0.5022
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 56s 542ms/step - accuracy: 0.8534 - loss: 0.5020 - val_accuracy: 0.9300 - val_loss: 0.2975 - learning_rate: 1.0000e-05
# Epoch 6/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.8642 - loss: 0.4561
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 537ms/step - accuracy: 0.8643 - loss: 0.4560 - val_accuracy: 0.9380 - val_loss: 0.2870 - learning_rate: 1.0000e-05
# Epoch 7/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.8889 - loss: 0.3993
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 56s 544ms/step - accuracy: 0.8888 - loss: 0.3995 - val_accuracy: 0.9380 - val_loss: 0.2792 - learning_rate: 1.0000e-05
# Epoch 8/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 535ms/step - accuracy: 0.8838 - loss: 0.4313 - val_accuracy: 0.9330 - val_loss: 0.2798 - learning_rate: 1.0000e-05
# Epoch 9/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.8917 - loss: 0.4082
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 543ms/step - accuracy: 0.8917 - loss: 0.4082 - val_accuracy: 0.9400 - val_loss: 0.2725 - learning_rate: 1.0000e-05
# Epoch 10/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.8760 - loss: 0.4321
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 56s 544ms/step - accuracy: 0.8761 - loss: 0.4318 - val_accuracy: 0.9380 - val_loss: 0.2677 - learning_rate: 1.0000e-05
# Epoch 11/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.8969 - loss: 0.3841
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 541ms/step - accuracy: 0.8968 - loss: 0.3842 - val_accuracy: 0.9420 - val_loss: 0.2646 - learning_rate: 1.0000e-05
# Epoch 12/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.8903 - loss: 0.4117
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 56s 544ms/step - accuracy: 0.8903 - loss: 0.4116 - val_accuracy: 0.9410 - val_loss: 0.2599 - learning_rate: 1.0000e-05
# Epoch 13/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.9033 - loss: 0.3578
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 56s 549ms/step - accuracy: 0.9032 - loss: 0.3580 - val_accuracy: 0.9420 - val_loss: 0.2576 - learning_rate: 1.0000e-05
# Epoch 14/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.8817 - loss: 0.3946
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 539ms/step - accuracy: 0.8818 - loss: 0.3945 - val_accuracy: 0.9420 - val_loss: 0.2550 - learning_rate: 1.0000e-05
# Epoch 15/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9034 - loss: 0.3657
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 541ms/step - accuracy: 0.9034 - loss: 0.3658 - val_accuracy: 0.9450 - val_loss: 0.2466 - learning_rate: 1.0000e-05
# Epoch 16/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.9036 - loss: 0.3571
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 56s 544ms/step - accuracy: 0.9036 - loss: 0.3571 - val_accuracy: 0.9450 - val_loss: 0.2463 - learning_rate: 1.0000e-05
# Epoch 17/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.9095 - loss: 0.3282
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 56s 544ms/step - accuracy: 0.9095 - loss: 0.3283 - val_accuracy: 0.9440 - val_loss: 0.2425 - learning_rate: 1.0000e-05
# Epoch 18/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.9075 - loss: 0.3414
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 537ms/step - accuracy: 0.9075 - loss: 0.3414 - val_accuracy: 0.9490 - val_loss: 0.2372 - learning_rate: 1.0000e-05
# Epoch 19/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.9180 - loss: 0.3278
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 56s 544ms/step - accuracy: 0.9180 - loss: 0.3279 - val_accuracy: 0.9480 - val_loss: 0.2336 - learning_rate: 1.0000e-05
# Epoch 20/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 81s 533ms/step - accuracy: 0.9165 - loss: 0.3298 - val_accuracy: 0.9460 - val_loss: 0.2355 - learning_rate: 1.0000e-05
# Epoch 21/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9105 - loss: 0.3298
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 541ms/step - accuracy: 0.9105 - loss: 0.3298 - val_accuracy: 0.9510 - val_loss: 0.2325 - learning_rate: 1.0000e-05
# Epoch 22/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.9190 - loss: 0.3166
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 543ms/step - accuracy: 0.9190 - loss: 0.3166 - val_accuracy: 0.9490 - val_loss: 0.2313 - learning_rate: 1.0000e-05
# Epoch 23/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9228 - loss: 0.3143
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 542ms/step - accuracy: 0.9227 - loss: 0.3143 - val_accuracy: 0.9540 - val_loss: 0.2240 - learning_rate: 1.0000e-05
# Epoch 24/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 55s 534ms/step - accuracy: 0.9272 - loss: 0.3003 - val_accuracy: 0.9500 - val_loss: 0.2277 - learning_rate: 1.0000e-05
# Epoch 25/25
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 532ms/step - accuracy: 0.9118 - loss: 0.3220 - val_accuracy: 0.9500 - val_loss: 0.2272 - learning_rate: 1.0000e-05
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9550 - loss: 0.2353
#
# ✅ Test Accuracy: 96.37%
# ✅ Test Loss: 0.2024
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     01_TUMOR       0.98      0.97      0.97        93
#    02_STROMA       0.96      0.91      0.93        93
#   03_COMPLEX       0.89      0.95      0.92        93
#    04_LYMPHO       0.98      0.94      0.96        93
#    05_DEBRIS       0.93      0.97      0.95        93
#    06_MUCOSA       0.99      0.98      0.98        93
#   07_ADIPOSE       1.00      1.00      1.00        93
#     08_EMPTY       1.00      1.00      1.00        93
#
#     accuracy                           0.96       744
#    macro avg       0.96      0.96      0.96       744
# weighted avg       0.96      0.96      0.96       744
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Final Model Saved at /content/colorectal_resnet50_finetuned_final.h5

# %%
import os, glob, shutil, random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet import preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras import regularizers, callbacks, optimizers

print("✅ Libraries ready")

# ==========================================================
# 📦 ZIP Extraction
# ==========================================================
ZIP_IN_DRIVE = "/content/drive/MyDrive/archive.zip"  # change if needed

if not os.path.exists(ZIP_IN_DRIVE):
    raise FileNotFoundError("❌ ZIP_IN_DRIVE path is not set correctly.")

EXTRACT_DIR = "/content/Extracted_Kather"
if os.path.exists(EXTRACT_DIR):
    shutil.rmtree(EXTRACT_DIR)
os.makedirs(EXTRACT_DIR, exist_ok=True)

print(f"📦 Unzipping dataset from:\n→ {ZIP_IN_DRIVE}")
# !unzip -q -o "$ZIP_IN_DRIVE" -d "$EXTRACT_DIR"

def find_dataset_root(base):
    best, best_count = base, 0
    for root, dirs, _ in os.walk(base):
        if len(dirs) > best_count:
            best, best_count = root, len(dirs)
    return best

SOURCE_DIR = find_dataset_root(EXTRACT_DIR)
print(f"✅ Dataset root detected at: {SOURCE_DIR}")

# ==========================================================
# ⚙️ Reproducibility & Split Ratios
# ==========================================================
SEED = 42
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)
VAL_RATIO = 0.20
TEST_RATIO = 0.15
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EXTS = (".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff")

# ==========================================================
# 🔎 Discover Classes
# ==========================================================
def list_images_recursive(folder):
    out = []
    for root, _, files in os.walk(folder):
        for fn in files:
            if os.path.splitext(fn)[1].lower() in EXTS:
                out.append(os.path.join(root, fn))
    return sorted(out)

class_to_files = {}
for cls in sorted(os.listdir(SOURCE_DIR)):
    p = os.path.join(SOURCE_DIR, cls)
    if os.path.isdir(p):
        files = list_images_recursive(p)
        if files:
            class_to_files[cls] = files

available_classes = sorted(class_to_files.keys())
print("\n📚 Classes detected:")
for c in available_classes:
    print(f"  - {c}: {len(class_to_files[c])} images")

# ==========================================================
# 🧩 Stratified Split
# ==========================================================
SPLIT_ROOT = "/content/kather_split_resnet"
TRAIN_DIR, VAL_DIR, TEST_DIR = [f"{SPLIT_ROOT}/{x}" for x in ["train", "val", "test"]]
if os.path.exists(SPLIT_ROOT):
    shutil.rmtree(SPLIT_ROOT)
os.makedirs(TRAIN_DIR); os.makedirs(VAL_DIR); os.makedirs(TEST_DIR)

def allocate_counts(n, val_ratio=VAL_RATIO, test_ratio=TEST_RATIO):
    if n <= 0: return (0,0,0)
    if n == 1: return (1,0,0)
    if n == 2: return (1,0,1)
    test_n = max(1, int(n * test_ratio))
    val_n  = max(1, int(n * val_ratio))
    if test_n + val_n >= n:
        val_n = 1; test_n = 1
    train_n = n - val_n - test_n
    return (train_n, val_n, test_n)

rng = np.random.default_rng(SEED)
totals = {"train":0,"val":0,"test":0}

for cls in available_classes:
    files = class_to_files[cls]
    idx = np.arange(len(files))
    rng.shuffle(idx)

    train_n, val_n, test_n = allocate_counts(len(files))
    train_idx = set(idx[:train_n])
    val_idx   = set(idx[train_n:train_n+val_n])
    test_idx  = set(idx[train_n+val_n:train_n+val_n+test_n])

    os.makedirs(f"{TRAIN_DIR}/{cls}")
    os.makedirs(f"{VAL_DIR}/{cls}")
    os.makedirs(f"{TEST_DIR}/{cls}")

    for i in idx:
        src = files[i]; base = os.path.basename(src)
        if i in train_idx: dst = f"{TRAIN_DIR}/{cls}/{base}"
        elif i in val_idx: dst = f"{VAL_DIR}/{cls}/{base}"
        else:              dst = f"{TEST_DIR}/{cls}/{base}"
        shutil.copy2(src, dst)

    totals["train"] += train_n
    totals["val"]   += val_n
    totals["test"]  += test_n

print("\n✅ Stratified Split Completed:", totals)

# ==========================================================
# 🔄 Data Generators
# ==========================================================
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25, width_shift_range=0.2, height_shift_range=0.2,
    zoom_range=0.3, horizontal_flip=True, vertical_flip=True,
    brightness_range=[0.8,1.2], shear_range=0.2, fill_mode="reflect"
)
val_test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_gen = train_datagen.flow_from_directory(TRAIN_DIR, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True)
val_gen   = val_test_datagen.flow_from_directory(VAL_DIR, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
test_gen  = val_test_datagen.flow_from_directory(TEST_DIR, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False)
class_names = list(train_gen.class_indices.keys())
num_classes = len(class_names)
print(f"\n✅ Detected {num_classes} classes: {class_names}")

# ==========================================================
# 🧠 Build Model (ResNet50)
# ==========================================================
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=IMG_SIZE + (3,))
base_model.trainable = False
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    BatchNormalization(),
    Dense(512, activation='relu', kernel_regularizer=regularizers.l2(1e-4)),
    Dropout(0.5),
    Dense(256, activation='relu'),
    Dropout(0.3),
    Dense(num_classes, activation='softmax')
])
model.compile(optimizer=optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())

# ==========================================================
# 🎯 PPO Agent for Adaptive Learning Rate
# ==========================================================
class PPOAgent:
    def __init__(self, lr=1e-4, clip=0.2, lr_bounds=(1e-6, 1e-3)):
        self.lr = lr
        self.clip = clip
        self.lr_bounds = lr_bounds
        self.old_reward = 0.0
    def act(self, reward):
        adv = reward - self.old_reward
        change = np.clip(adv, -self.clip, self.clip)
        self.lr *= (1 + change)
        self.lr = np.clip(self.lr, *self.lr_bounds)
        self.old_reward = reward
        return self.lr

ppo = PPOAgent(lr=1e-4)

# ==========================================================
# 🏋️ Training with PPO-Controlled LR
# ==========================================================
EPOCHS_INITIAL = 15
best_val_acc = 0
lr_track, reward_track = [], []

for epoch in range(EPOCHS_INITIAL):
    hist = model.fit(train_gen, validation_data=val_gen, epochs=1, verbose=1)
    val_acc = hist.history['val_accuracy'][-1]
    lr = ppo.act(val_acc)
    model.optimizer.learning_rate.assign(lr)
    lr_track.append(lr)
    reward_track.append(val_acc)
    print(f"🔁 Epoch {epoch+1}/{EPOCHS_INITIAL} | Val Acc: {val_acc:.4f} | New LR: {lr:.6f}")

# ==========================================================
# 🔓 Fine-tuning Phase
# ==========================================================
base_model.trainable = True
for layer in base_model.layers[:100]:
    layer.trainable = False

model.compile(optimizer=optimizers.Adam(learning_rate=ppo.lr), loss='categorical_crossentropy', metrics=['accuracy'])
EPOCHS_FINE = 25

for epoch in range(EPOCHS_FINE):
    hist = model.fit(train_gen, validation_data=val_gen, epochs=1, verbose=1)
    val_acc = hist.history['val_accuracy'][-1]
    lr = ppo.act(val_acc)
    model.optimizer.learning_rate.assign(lr)
    lr_track.append(lr)
    reward_track.append(val_acc)
    print(f"🧠 Fine Epoch {epoch+1}/{EPOCHS_FINE} | Val Acc: {val_acc:.4f} | New LR: {lr:.6f}")

# ==========================================================
# 🧾 Evaluation
# ==========================================================
test_loss, test_acc = model.evaluate(test_gen, verbose=1)
print(f"\n✅ Test Accuracy: {test_acc*100:.2f}%")
print(f"✅ Test Loss: {test_loss:.4f}")

y_true = test_gen.classes
y_pred = np.argmax(model.predict(test_gen, verbose=0), axis=1)
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix — ResNet50 + PPO")
plt.xlabel("Predicted"); plt.ylabel("Actual"); plt.show()

print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=class_names))

# ==========================================================
# 📊 PPO Dynamics Visualization
# ==========================================================
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(reward_track, label='Validation Accuracy')
plt.title("Validation Accuracy per Epoch"); plt.legend()
plt.subplot(1,2,2)
plt.plot(lr_track, label='Learning Rate (PPO)')
plt.title("PPO Adaptive Learning Rate"); plt.legend()S
plt.show()

# ==========================================================
# 💾 Save Model
# ==========================================================
model.save('/content/resnet50_colorectal_PPO_finetuned.h5')
print("✅ Saved Model: /content/resnet50_colorectal_PPO_finetuned.h5")
# Out:
# ✅ Libraries ready
# 📦 Unzipping dataset from:
# → /content/drive/MyDrive/archive.zip
# ✅ Dataset root detected at: /content/Extracted_Kather/Kather_texture_2016_image_tiles_5000/Kather_texture_2016_image_tiles_5000
#
# 📚 Classes detected:
#   - 01_TUMOR: 625 images
#   - 02_STROMA: 625 images
#   - 03_COMPLEX: 625 images
#   - 04_LYMPHO: 625 images
#   - 05_DEBRIS: 625 images
#   - 06_MUCOSA: 625 images
#   - 07_ADIPOSE: 625 images
#   - 08_EMPTY: 625 images
#
# ✅ Stratified Split Completed: {'train': 3256, 'val': 1000, 'test': 744}
# Found 3256 images belonging to 8 classes.
# Found 1000 images belonging to 8 classes.
# Found 744 images belonging to 8 classes.
#
# ✅ Detected 8 classes: ['01_TUMOR', '02_STROMA', '03_COMPLEX', '04_LYMPHO', '05_DEBRIS', '06_MUCOSA', '07_ADIPOSE', '08_EMPTY']
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 2048)           │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 8)              │         2,056 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,778,376 (94.52 MB)
#  Trainable params: 1,186,568 (4.53 MB)
#  Non-trainable params: 23,591,808 (90.00 MB)
# None
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 77s 639ms/step - accuracy: 0.3905 - loss: 1.9473 - val_accuracy: 0.7680 - val_loss: 0.8198
# 🔁 Epoch 1/15 | Val Acc: 0.7680 | New LR: 0.000120
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 53s 516ms/step - accuracy: 0.6854 - loss: 0.9893 - val_accuracy: 0.8460 - val_loss: 0.5622
# 🔁 Epoch 2/15 | Val Acc: 0.8460 | New LR: 0.000129
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 53s 520ms/step - accuracy: 0.7563 - loss: 0.8125 - val_accuracy: 0.8670 - val_loss: 0.4363
# 🔁 Epoch 3/15 | Val Acc: 0.8670 | New LR: 0.000132
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 526ms/step - accuracy: 0.7846 - loss: 0.7002 - val_accuracy: 0.8870 - val_loss: 0.4032
# 🔁 Epoch 4/15 | Val Acc: 0.8870 | New LR: 0.000135
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 51s 498ms/step - accuracy: 0.8078 - loss: 0.6456 - val_accuracy: 0.8900 - val_loss: 0.3722
# 🔁 Epoch 5/15 | Val Acc: 0.8900 | New LR: 0.000135
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 50s 494ms/step - accuracy: 0.8217 - loss: 0.6120 - val_accuracy: 0.8990 - val_loss: 0.3522
# 🔁 Epoch 6/15 | Val Acc: 0.8990 | New LR: 0.000136
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 512ms/step - accuracy: 0.8299 - loss: 0.5799 - val_accuracy: 0.9050 - val_loss: 0.3394
# 🔁 Epoch 7/15 | Val Acc: 0.9050 | New LR: 0.000137
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 514ms/step - accuracy: 0.8537 - loss: 0.4988 - val_accuracy: 0.9030 - val_loss: 0.3453
# 🔁 Epoch 8/15 | Val Acc: 0.9030 | New LR: 0.000137
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 508ms/step - accuracy: 0.8575 - loss: 0.5087 - val_accuracy: 0.9130 - val_loss: 0.3313
# 🔁 Epoch 9/15 | Val Acc: 0.9130 | New LR: 0.000138
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 52s 505ms/step - accuracy: 0.8521 - loss: 0.5106 - val_accuracy: 0.9100 - val_loss: 0.3237
# 🔁 Epoch 10/15 | Val Acc: 0.9100 | New LR: 0.000138
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 51s 502ms/step - accuracy: 0.8617 - loss: 0.4894 - val_accuracy: 0.9180 - val_loss: 0.3158
# 🔁 Epoch 11/15 | Val Acc: 0.9180 | New LR: 0.000139
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 53s 519ms/step - accuracy: 0.8595 - loss: 0.4532 - val_accuracy: 0.9120 - val_loss: 0.3290
# 🔁 Epoch 12/15 | Val Acc: 0.9120 | New LR: 0.000138
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 51s 496ms/step - accuracy: 0.8803 - loss: 0.4328 - val_accuracy: 0.9120 - val_loss: 0.3169
# 🔁 Epoch 13/15 | Val Acc: 0.9120 | New LR: 0.000138
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 53s 518ms/step - accuracy: 0.8611 - loss: 0.4703 - val_accuracy: 0.9230 - val_loss: 0.3098
# 🔁 Epoch 14/15 | Val Acc: 0.9230 | New LR: 0.000140
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 53s 516ms/step - accuracy: 0.8780 - loss: 0.4357 - val_accuracy: 0.9290 - val_loss: 0.2971
# 🔁 Epoch 15/15 | Val Acc: 0.9290 | New LR: 0.000140
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 103s 714ms/step - accuracy: 0.8303 - loss: 0.5864 - val_accuracy: 0.9160 - val_loss: 0.3159
# 🧠 Fine Epoch 1/25 | Val Acc: 0.9160 | New LR: 0.000139
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 53s 518ms/step - accuracy: 0.8760 - loss: 0.4164 - val_accuracy: 0.9310 - val_loss: 0.2794
# 🧠 Fine Epoch 2/25 | Val Acc: 0.9310 | New LR: 0.000141
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 526ms/step - accuracy: 0.8749 - loss: 0.4479 - val_accuracy: 0.9360 - val_loss: 0.2918
# 🧠 Fine Epoch 3/25 | Val Acc: 0.9360 | New LR: 0.000141
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 56s 550ms/step - accuracy: 0.9005 - loss: 0.4155 - val_accuracy: 0.9250 - val_loss: 0.2828
# 🧠 Fine Epoch 4/25 | Val Acc: 0.9250 | New LR: 0.000140
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 528ms/step - accuracy: 0.9108 - loss: 0.3862 - val_accuracy: 0.9390 - val_loss: 0.2371
# 🧠 Fine Epoch 5/25 | Val Acc: 0.9390 | New LR: 0.000142
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 525ms/step - accuracy: 0.9125 - loss: 0.3269 - val_accuracy: 0.9430 - val_loss: 0.2596
# 🧠 Fine Epoch 6/25 | Val Acc: 0.9430 | New LR: 0.000142
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 528ms/step - accuracy: 0.9285 - loss: 0.2948 - val_accuracy: 0.9500 - val_loss: 0.2288
# 🧠 Fine Epoch 7/25 | Val Acc: 0.9500 | New LR: 0.000143
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 530ms/step - accuracy: 0.9331 - loss: 0.2674 - val_accuracy: 0.9550 - val_loss: 0.2095
# 🧠 Fine Epoch 8/25 | Val Acc: 0.9550 | New LR: 0.000144
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 525ms/step - accuracy: 0.9288 - loss: 0.2987 - val_accuracy: 0.9490 - val_loss: 0.2175
# 🧠 Fine Epoch 9/25 | Val Acc: 0.9490 | New LR: 0.000143
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 521ms/step - accuracy: 0.9371 - loss: 0.2759 - val_accuracy: 0.9580 - val_loss: 0.2010
# 🧠 Fine Epoch 10/25 | Val Acc: 0.9580 | New LR: 0.000145
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 53s 518ms/step - accuracy: 0.9339 - loss: 0.3040 - val_accuracy: 0.9560 - val_loss: 0.2180
# 🧠 Fine Epoch 11/25 | Val Acc: 0.9560 | New LR: 0.000144
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 528ms/step - accuracy: 0.9495 - loss: 0.2549 - val_accuracy: 0.9580 - val_loss: 0.2434
# 🧠 Fine Epoch 12/25 | Val Acc: 0.9580 | New LR: 0.000145
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 529ms/step - accuracy: 0.9389 - loss: 0.2934 - val_accuracy: 0.9430 - val_loss: 0.2461
# 🧠 Fine Epoch 13/25 | Val Acc: 0.9430 | New LR: 0.000142
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 528ms/step - accuracy: 0.9361 - loss: 0.2587 - val_accuracy: 0.9590 - val_loss: 0.2038
# 🧠 Fine Epoch 14/25 | Val Acc: 0.9590 | New LR: 0.000145
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 532ms/step - accuracy: 0.9343 - loss: 0.3064 - val_accuracy: 0.9480 - val_loss: 0.2807
# 🧠 Fine Epoch 15/25 | Val Acc: 0.9480 | New LR: 0.000143
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 533ms/step - accuracy: 0.9405 - loss: 0.2578 - val_accuracy: 0.9610 - val_loss: 0.2085
# 🧠 Fine Epoch 16/25 | Val Acc: 0.9610 | New LR: 0.000145
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 53s 520ms/step - accuracy: 0.9413 - loss: 0.2594 - val_accuracy: 0.9580 - val_loss: 0.2122
# 🧠 Fine Epoch 17/25 | Val Acc: 0.9580 | New LR: 0.000144
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 528ms/step - accuracy: 0.9572 - loss: 0.2108 - val_accuracy: 0.9520 - val_loss: 0.2362
# 🧠 Fine Epoch 18/25 | Val Acc: 0.9520 | New LR: 0.000144
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 528ms/step - accuracy: 0.9548 - loss: 0.2146 - val_accuracy: 0.9480 - val_loss: 0.2339
# 🧠 Fine Epoch 19/25 | Val Acc: 0.9480 | New LR: 0.000143
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 530ms/step - accuracy: 0.9535 - loss: 0.2105 - val_accuracy: 0.9580 - val_loss: 0.2171
# 🧠 Fine Epoch 20/25 | Val Acc: 0.9580 | New LR: 0.000144
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 528ms/step - accuracy: 0.9458 - loss: 0.2329 - val_accuracy: 0.9710 - val_loss: 0.1789
# 🧠 Fine Epoch 21/25 | Val Acc: 0.9710 | New LR: 0.000146
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 53s 523ms/step - accuracy: 0.9621 - loss: 0.2053 - val_accuracy: 0.9660 - val_loss: 0.2007
# 🧠 Fine Epoch 22/25 | Val Acc: 0.9660 | New LR: 0.000146
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 53s 519ms/step - accuracy: 0.9561 - loss: 0.2020 - val_accuracy: 0.9700 - val_loss: 0.1985
# 🧠 Fine Epoch 23/25 | Val Acc: 0.9700 | New LR: 0.000146
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 526ms/step - accuracy: 0.9548 - loss: 0.2269 - val_accuracy: 0.9610 - val_loss: 0.2102
# 🧠 Fine Epoch 24/25 | Val Acc: 0.9610 | New LR: 0.000145
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 54s 525ms/step - accuracy: 0.9449 - loss: 0.2408 - val_accuracy: 0.9560 - val_loss: 0.2341
# 🧠 Fine Epoch 25/25 | Val Acc: 0.9560 | New LR: 0.000144
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9327 - loss: 0.2768
#
# ✅ Test Accuracy: 95.30%
# ✅ Test Loss: 0.2251
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     01_TUMOR       0.98      0.95      0.96        93
#    02_STROMA       0.97      0.82      0.89        93
#   03_COMPLEX       0.78      0.97      0.87        93
#    04_LYMPHO       0.97      0.96      0.96        93
#    05_DEBRIS       0.98      0.99      0.98        93
#    06_MUCOSA       1.00      0.99      0.99        93
#   07_ADIPOSE       0.99      0.97      0.98        93
#     08_EMPTY       1.00      0.99      0.99        93
#
#     accuracy                           0.95       744
#    macro avg       0.96      0.95      0.95       744
# weighted avg       0.96      0.95      0.95       744
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Saved Model: /content/resnet50_colorectal_PPO_finetuned.h5
